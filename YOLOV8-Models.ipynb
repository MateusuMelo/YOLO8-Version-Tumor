# %%
# %pip -q install roboflow
# %pip -q install ultralytics==8.0.28
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 36.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.6/272.6 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.6/248.6 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.4 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
HOME = os.getcwd() + "/drive/MyDrive"
print(HOME)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="OZmt7veKofDCRjgyQ5XE")
project = rf.workspace("csilab").project("csilab-braintumor")
dataset = project.version(3).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.28, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to CsiLab-BrainTumor-3 in yolov8:: 100%|██████████| 618/618 [00:00<00:00, 10489.58it/s]

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/CsiLab-BrainTumor-3/data.yaml" epochs=1000 imgsz=640 batch=-1 workers=320 patience=0
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data="/content/CsiLab-BrainTumor-3/data.yaml" epochs=1000 imgsz=640 batch=-1 workers=320 patience=0
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#                    all         61         67   0.000765      0.209   0.000595   0.000208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000      32.6G      1.038      3.846      1.339        114        640: 100% 3/3 [00:03<00:00,  1.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.52s/it]
#                    all         61         67     0.0249      0.119     0.0107    0.00778
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000      32.6G     0.8596      2.735      1.212        112        640: 100% 3/3 [00:03<00:00,  1.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all         61         67      0.575      0.522      0.526      0.434
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data="/content/CsiLab-BrainTumor-3/data.yaml" epochs=1000 imgsz=640 batch=-1 workers=320 patience=0
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#                    all         61         67      0.701      0.526      0.597      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000      29.6G     0.6805      1.816      1.103         45        640: 100% 5/5 [00:03<00:00,  1.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.76s/it]
#                    all         61         67       0.77      0.537      0.627      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000      29.6G     0.6539      1.213      1.097         40        640: 100% 5/5 [00:04<00:00,  1.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.71s/it]
#                    all         61         67      0.871      0.605      0.702      0.591
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data="/content/CsiLab-BrainTumor-3/data.yaml" epochs=1000 imgsz=640 batch=-1 workers=320 patience=0
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#                    all         61         67      0.791      0.493      0.578      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000      32.5G     0.7269      1.536      1.169          4        640: 100% 7/7 [00:05<00:00,  1.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.94s/it]
#                    all         61         67      0.681      0.448      0.504      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000      32.5G     0.6706      1.167      1.108          4        640: 100% 7/7 [00:04<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.92s/it]
#                    all         61         67      0.575      0.463       0.51      0.422
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="/content/CsiLab-BrainTumor-3/data.yaml" epochs=1000 imgsz=640 batch=-1 workers=320 patience=0
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#                    all         61         67    0.00208      0.567    0.00378    0.00223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000      28.2G      1.047      3.761      1.305        395        640: 100% 1/1 [00:06<00:00,  6.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.67s/it]
#                    all         61         67    0.00213      0.582    0.00373    0.00227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000      28.2G       1.11      3.759      1.368        406        640: 100% 1/1 [00:06<00:00,  6.74s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.69s/it]
#                    all         61         67    0.00208      0.567    0.00391    0.00248
#
# ...

# %%
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train5/ (stored 0%)
#   adding: content/runs/detect/train5/F1_curve.png (deflated 18%)
#   adding: content/runs/detect/train5/val_batch0_pred.jpg (deflated 21%)
#   adding: content/runs/detect/train5/train_batch992.jpg (deflated 11%)
#   adding: content/runs/detect/train5/args.yaml (deflated 51%)
#   adding: content/runs/detect/train5/results.csv (deflated 86%)
#   adding: content/runs/detect/train5/train_batch2.jpg (deflated 6%)
#   adding: content/runs/detect/train5/weights/ (stored 0%)
#   adding: content/runs/detect/train5/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train5/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train5/PR_curve.png (deflated 22%)
#   adding: content/runs/detect/train5/train_batch990.jpg (deflated 18%)
#   adding: content/runs/detect/train5/events.out.tfevents.1700080424.2eace8111d6d.393641.0 (deflated 71%)
# ...

# %%
from google.colab import files
files.download("/content/runs.zip")

# %%
# %cp -av "/content/runs" "/content/drive/MyDrive"
# Out:
# cp: cannot create directory '/content/drive/MyDrive': No such file or directory
