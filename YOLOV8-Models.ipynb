# %%
# %pip -q install roboflow
# %pip -q install ultralytics==8.0.28
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.6/272.6 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
HOME = os.getcwd() + "/drive/MyDrive"
print(HOME)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="OZmt7veKofDCRjgyQ5XE")
project = rf.workspace("csilab").project("csilab-braintumor")
dataset = project.version(3).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.207, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to CsiLab-BrainTumor-3 in yolov8:: 100%|██████████| 618/618 [00:00<00:00, 1830.38it/s]

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model='/content/runs/detect/train8/weights/best.pt' data="/content/drive/MyDrive/CsiLab-BrainTumor-3/data.yaml" epochs=1000 imgsz=640 batch=32 workers=320 patience=0 resume=true
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cp -av "/content/runs" "/content/drive/MyDrive"
# Out:
# cp: cannot create directory '/content/drive/MyDrive': No such file or directory
